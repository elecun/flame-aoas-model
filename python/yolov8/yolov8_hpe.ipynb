# %%
from ultralytics import YOLO
import os
import matplotlib.pyplot as plt
import cv2
import datetime

# %%
# Load a model
model = YOLO('./models/yolov8x-pose.pt')  # load an official model

# Predict with the model
start = datetime.datetime.now()
results = model('../../images/test3.png')  # predict on an image
end = datetime.datetime.now()
print(f"Elapsed time (us) : {(end-start).microseconds}")
annotated_frame = results[0].plot()

# %matplotlib inline
plt.figure(figsize=(30, 7))
plt.axis('off')
plt.imshow(annotated_frame)
# Out:
# image 1/1 /home/iae/dev/flame-aoas-model/python/yolov8/../../images/test3.png: 384x640 1 person, 8.3ms
# Speed: 1.1ms preprocess, 8.3ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Elapsed time (us) : 384372
